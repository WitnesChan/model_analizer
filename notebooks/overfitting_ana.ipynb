# %%
import pickle 
import pandas as pd
import numpy as np
import seaborn as sns

# %%
trials =pickle.load(open('trial_results_v2.sav', 'rb'))
df_trials = pd.DataFrame(trials.trials)

# %%
df_trials = pd.concat(
   [ df_trials['misc'].apply(lambda r: pd.Series(r['vals'])).applymap(lambda r: r[0]),  df_trials['result'].apply(lambda r: r['loss']).rename('loss')],
   axis = 1
)

# %%
df_trials
# Out:
#     boosting_type  colsample_by_tree  learning_rat  max_depth  n_estimators  \
# 0               1           0.986408      0.383188        7.0          99.0
# 1               0           0.986389      0.722344       11.0          64.0
# 2               1           0.413948      0.183031       11.0          91.0
# 3               1           0.539489      0.173966        7.0          38.0
# 4               0           0.775105      0.657532       10.0          50.0
# ..            ...                ...           ...        ...           ...
# 95              0           0.701781      0.223365       12.0          95.0
# 96              1           0.560224      0.547068        6.0          62.0
# 97              0           0.741256      0.628972       13.0          74.0
# 98              0           0.350539      0.473059       14.0          98.0
# 99              0           0.913768      0.738064       13.0         100.0
#
#     num_leaves  reg_lambda      loss
# ...

# %%
sns.pairplot(data = df_trials, kind="kde")

# %%
sns.regplot(data = df_trials , x = 'colsample_by_tree', y ='loss')
# Out:
# <AxesSubplot:xlabel='colsample_by_tree', ylabel='loss'>

# %%
sns.regplot(data = df_trials , x = 'max_depth', y ='loss')
# Out:
# <AxesSubplot:xlabel='max_depth', ylabel='loss'>

# %%
sns.regplot(data = df_trials , x = 'n_estimators', y ='loss')
# Out:
# <AxesSubplot:xlabel='n_estimators', ylabel='loss'>
